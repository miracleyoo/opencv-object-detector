# %%
import glob
import os
import shutil
import cv2
import numpy as np
import matplotlib.pyplot as plt

from tqdm import tqdm
from PIL import Image
from sklearn.svm import LinearSVC
from skimage.feature import hog
from skimage.feature import haar_like_feature
from skimage.feature import local_binary_pattern as lbp
from skimage.io import imread
from skimage.transform import pyramid_gaussian, integral_image
from sklearn.externals import joblib

# %matplotlib inline

# %%
class Config(object):
    def __init__(self):
        
        # General Config
        self.DES_TYPE = "LBP"
        self.PROJECT_ID = "no_hands_" + self.DES_TYPE
        self.THRESHOLD = 0.3
        self.CLF_TYPE = "LIN_SVM"
        self.DOWNSCALE = 1.25
        
        # Pathes
        self.DIR_PATHS = {
            "POS_FEAT_PH"    : os.path.join("./source/features", self.PROJECT_ID,"pos"),
            "NEG_FEAT_PH"    : os.path.join("./source/features", self.PROJECT_ID,"neg"),
            "MODEL_DIR_PH"   : os.path.join("./source/models", self.PROJECT_ID),
            "POS_IMG_PH"     : "./source/images/pos",
            "NEG_IMG_PH"     : "./source/images/neg",
            "TEST_IMG_DIR_PH": "./source/test_images"
        }
        self.MODEL_PH = os.path.join(self.DIR_PATHS["MODEL_DIR_PH"], "svm.model")
        self.TEST_IMG_PH = os.path.join(self.DIR_PATHS["TEST_IMG_DIR_PH"], "test.jpg")
        
        # HOG Features
        self.MIN_WDW_SIZE = [64, 64]
        self.STEP_SIZE = [12, 12]
        self.ORIENTATIONS = 9
        self.PIXELS_PER_CELL = [3, 3]
        self.CELLS_PER_BLOCK = [3, 3]
        self.VISUALIZE = False
        self.NORMALIZE = True

        # LBP Features
        self.LBP_RADIUS = 5
        self.LBP_POINTS = 8 * self.LBP_RADIUS

args = Config()
for ph in args.DIR_PATHS.values():
    if not os.path.exists(ph):
        os.makedirs(ph)
        print("==> Directory Tree",ph,"created")

# %%
def process_image(image, args=args):
    if args.DES_TYPE == "HOG":
        fd = hog(image, block_norm='L2', pixels_per_cell=args.PIXELS_PER_CELL)
    elif args.DES_TYPE == "LBP":
        fd = lbp(image, args.LBP_POINTS, args.LBP_RADIUS)
    elif args.DES_TYPE == "HAAR":
        fd = haar_like_feature(integral_image(image), 0, 0, 5, 5, 'type-3-x')
    else:
        raise KeyError("==> The Processing method does not exist!")
    return fd

def extract_features(args=args):
    if os.path.exist(args.DIR_PATHS["POS_FEAT_PH"]):
        shutil.rmtree(args.DIR_PATHS["POS_FEAT_PH"])
    if os.path.exist(args.DIR_PATHS["NEG_FEAT_PH"]):
        shutil.rmtree(args.DIR_PATHS["NEG_FEAT_PH"])
    os.makedirs(args.DIR_PATHS["POS_FEAT_PH"])
    os.makedirs(args.DIR_PATHS["NEG_FEAT_PH"])
    
    print("==> Calculating the descriptors for the positive samples and saving them")
    for im_path in tqdm(glob.glob(os.path.join(args.DIR_PATHS["POS_IMG_PH"], "*"))):
        im = imread(im_path, as_grey=True)
        fd = process_image(im)
        fd_name = os.path.split(im_path)[1].split(".")[0] + ".feat"
        fd_path = os.path.join(args.DIR_PATHS["POS_FEAT_PH"], fd_name)
        joblib.dump(fd, fd_path)
    print("==> Positive features saved in {}".format(args.DIR_PATHS["POS_FEAT_PH"]))

    print("==> Calculating the descriptors for the negative samples and saving them")
    for im_path in tqdm(glob.glob(os.path.join(args.DIR_PATHS["NEG_IMG_PH"], "*"))):
        im = imread(im_path, as_grey=True)
        fd = process_image(im)
        fd_name = os.path.split(im_path)[1].split(".")[0] + ".feat"
        fd_path = os.path.join(args.DIR_PATHS["NEG_FEAT_PH"], fd_name)
        joblib.dump(fd, fd_path)
    print("==> Negative features saved in {}".format(args.DIR_PATHS["NEG_FEAT_PH"]))
    print("==> Completed calculating features from training images")

# %%
def train_classifier(args=args):
    fds = []
    labels = []
    print("==> Loading the positive features")
    for feat_path in tqdm(glob.glob(os.path.join(args.DIR_PATHS["POS_FEAT_PH"], "*.feat"))):
        fd = joblib.load(feat_path)
        fds.append(fd.reshape(-1))
        labels.append(1)

    print("==> Load the negative features")
    for feat_path in tqdm(glob.glob(os.path.join(args.DIR_PATHS["NEG_FEAT_PH"], "*.feat"))):
        fd = joblib.load(feat_path)
        fds.append(fd.reshape(-1))
        labels.append(0)

    if args.CLF_TYPE is "LIN_SVM":
        clf = LinearSVC()
        print("==> Training a Linear SVM Classifier")
        clf.fit(fds, labels)
        joblib.dump(clf, args.MODEL_PH)
        print("==> Classifier saved to {}".format(args.MODEL_PH))

# %%
def overlapping_area(detection_1, detection_2):
    """
        Function to calculate overlapping area'si
        `detection_1` and `detection_2` are 2 detections whose area
        of overlap needs to be found out.
        Each detection is list in the format ->
        [x-top-left, y-top-left, confidence-of-detections, width-of-detection, height-of-detection]
        The function returns a value between 0 and 1,
        which represents the area of overlap.
        0 is no overlap and 1 is complete overlap.
        Area calculated from ->
        http://math.stackexchange.com/questions/99565/simplest-way-to-calculate-the-intersect-area-of-two-rectangles
    """
    # Calculate the x-y co-ordinates of the rectangles
    x1_tl = detection_1[0]
    x2_tl = detection_2[0]
    x1_br = detection_1[0] + detection_1[3]
    x2_br = detection_2[0] + detection_2[3]
    y1_tl = detection_1[1]
    y2_tl = detection_2[1]
    y1_br = detection_1[1] + detection_1[4]
    y2_br = detection_2[1] + detection_2[4]
    # Calculate the overlapping Area
    x_overlap = max(0, min(x1_br, x2_br) - max(x1_tl, x2_tl))
    y_overlap = max(0, min(y1_br, y2_br) - max(y1_tl, y2_tl))
    overlap_area = x_overlap * y_overlap
    area_1 = detection_1[3] * detection_2[4]
    area_2 = detection_2[3] * detection_2[4]
    total_area = area_1 + area_2 - overlap_area
    return overlap_area / float(total_area)


def nms(detections, threshold=.5):
    """
        This function performs Non-Maxima Suppression.
        `detections` consists of a list of detections.
        Each detection is in the format ->
        [x-top-left, y-top-left, confidence-of-detections, width-of-detection, height-of-detection]
        If the area of overlap is greater than the `threshold`,
        the area with the lower confidence score is removed.
        The output is a list of detections.
    """
    if len(detections) == 0:
        return []
    # Sort the detections based on confidence score
    detections = sorted(detections, key=lambda detections: detections[2],
                        reverse=True)
    new_detections = [] # Unique detections will be appended to this list
    new_detections.append(detections[0]) # Append the first detection
    del detections[0] # Remove the detection from the original list
    """
        For each detection, calculate the overlapping area
        and if area of overlap is less than the threshold set
        for the detections in `new_detections`, append the 
        detection to `new_detections`.
        In either case, remove the detection from `detections` list.
    """
    for index, detection in enumerate(detections):
        for new_detection in new_detections:
            if overlapping_area(detection, new_detection) > threshold:
                del detections[index]
                break
        else:
            new_detections.append(detection)
            del detections[index]
    return new_detections

# %%
def resize_by_short(img, short_len=256):
    print(img.size)
    (x, y) = img.size
    if x > y:
        y_s = short_len
        x_s = int(x * y_s / y)
        img = img.resize((x_s, y_s))
    else:
        x_s = short_len
        y_s = int(y * x_s / x)
        img = img.resize((x_s, y_s))
    return img


def sliding_window(image, window_size, step_size):
    """
        This function returns a patch of the input image `image` of size equal
        to `window_size`. The first image returned top-left co-ordinates (0, 0)
        and are increment in both x and y directions by the `step_size` supplied.
        So, the input parameters are -
        * `image` - Input Image
        * `window_size` - Size of Sliding Window
        * `step_size` - Incremented Size of Window

        The function returns a tuple -
        (x, y, im_window)
        where
        * x is the top-left x co-ordinate
        * y is the top-left y co-ordinate
        * im_window is the sliding window image
    """
    for y in range(0, image.shape[0], step_size[1]):
        for x in range(0, image.shape[1], step_size[0]):
            yield (x, y, image[y:y + window_size[1], x:x + window_size[0]])


def test_classifier(args=args):
    # Read the Image
    im = Image.open(args.TEST_IMG_PH).convert('L')
    im = np.array(resize_by_short(im))

    clf = joblib.load(args.MODEL_PH) # Load the classifier
    detections = [] # List to store the detections
    scale = 0 # The current scale of the image
    
    # Downscale the image and iterate
    for im_scaled in pyramid_gaussian(im, downscale=args.DOWNSCALE):
        cd = [] # This list contains detections at the current scale
        # If the width or height of the scaled image is less than
        # the width or height of the window, then end the iterations.
        if im_scaled.shape[0] < args.MIN_WDW_SIZE[1] or im_scaled.shape[1] < args.MIN_WDW_SIZE[0]:
            break
        for (x, y, im_window) in sliding_window(im_scaled, args.MIN_WDW_SIZE, args.STEP_SIZE):
            if im_window.shape[0] != args.MIN_WDW_SIZE[1] or im_window.shape[1] != args.MIN_WDW_SIZE[0]:
                continue
            # Calculate the HOG features
            fd = process_image(im_window).reshape([1, -1])
            pred = clf.predict(fd)
            if pred == 1:
                print("Detection:: Location -> ({}, {})".format(x, y))
                print("Scale ->  {} | Confidence Score {} \n".format(scale, clf.decision_function(fd)))
                detections.append((x, y, clf.decision_function(fd),
                                   int(args.MIN_WDW_SIZE[0] * (args.DOWNSCALE ** scale)),
                                   int(args.MIN_WDW_SIZE[1] * (args.DOWNSCALE ** scale))))
                cd.append(detections[-1])
                
            # If visualize is set to true, display the working of the sliding window
            if args.VISUALIZE:
                clone = im_scaled.copy()
                for x1, y1, _, _, _ in cd:
                    # Draw the detections at this scale
                    cv2.rectangle(clone, (x1, y1), (x1 + im_window.shape[1], y1 +
                                                    im_window.shape[0]), (0, 0, 0), thickness=2)
                cv2.rectangle(clone, (x, y), (x + im_window.shape[1], y +
                                              im_window.shape[0]), (255, 255, 255), thickness=2)
                cv2.imshow("Sliding Window in Progress", clone)
                cv2.waitKey(30)
        
        # Move the the next scale
        scale += 1

    # Display the results before performing NMS
    clone = im.copy()
    
    # Draw the detections
    for (x_tl, y_tl, _, w, h) in detections:
        cv2.rectangle(im, (x_tl, y_tl), (x_tl + w, y_tl + h), (0, 0, 0), thickness=2)
    
    detections = nms(detections, args.THRESHOLD) # Perform Non Maxima Suppression

    # Display the results after performing NMS
    for (x_tl, y_tl, _, w, h) in detections:
        # Draw the detections
        cv2.rectangle(clone, (x_tl, y_tl), (x_tl + w, y_tl + h), (0, 0, 0), thickness=2)
    cv2.imshow("Final Detections after applying NMS", clone)
    cv2.imwrite('test1.jpg', clone)
    cv2.waitKey()

# %%
extract_features()
train_classifier()
test_classifier()
# Out:
# (3088, 2320)
# Detection:: Location -> (36, 0)
# Scale ->  0 | Confidence Score [198.27830949]
#
# Detection:: Location -> (48, 0)
# Scale ->  0 | Confidence Score [232.67722321]
#
# Detection:: Location -> (60, 0)
# Scale ->  0 | Confidence Score [111.24729182]
#
# Detection:: Location -> (72, 0)
# Scale ->  0 | Confidence Score [66.69772704]
#
# Detection:: Location -> (84, 0)
# Scale ->  0 | Confidence Score [85.11675513]
#
# Detection:: Location -> (96, 0)
# Scale ->  0 | Confidence Score [386.59124415]
#
# Detection:: Location -> (108, 0)
# Scale ->  0 | Confidence Score [8.18696862]
#
# Detection:: Location -> (120, 0)
# Scale ->  0 | Confidence Score [24.57719112]
#
# Detection:: Location -> (132, 0)
# Scale ->  0 | Confidence Score [31.23617957]
#
# Detection:: Location -> (144, 0)
# Scale ->  0 | Confidence Score [155.83525811]
#
# Detection:: Location -> (156, 0)
# Scale ->  0 | Confidence Score [54.98559311]
#
# Detection:: Location -> (168, 0)
# Scale ->  0 | Confidence Score [104.47967087]
#
# Detection:: Location -> (180, 0)
# Scale ->  0 | Confidence Score [191.87770993]
#
# Detection:: Location -> (192, 0)
# Scale ->  0 | Confidence Score [174.07435785]
#
# Detection:: Location -> (204, 0)
# Scale ->  0 | Confidence Score [91.02236618]
#
# Detection:: Location -> (216, 0)
# Scale ->  0 | Confidence Score [52.331026]
#
# Detection:: Location -> (228, 0)
# Scale ->  0 | Confidence Score [52.23763633]
#
# Detection:: Location -> (240, 0)
# Scale ->  0 | Confidence Score [92.42449058]
#
# Detection:: Location -> (252, 0)
# Scale ->  0 | Confidence Score [191.252415]
#
# Detection:: Location -> (264, 0)
# Scale ->  0 | Confidence Score [28.16503814]
#
# Detection:: Location -> (276, 0)
# Scale ->  0 | Confidence Score [51.62922094]
#
# Detection:: Location -> (0, 12)
# Scale ->  0 | Confidence Score [5.33211775]
#
# Detection:: Location -> (36, 12)
# Scale ->  0 | Confidence Score [193.11600664]
#
# Detection:: Location -> (48, 12)
# Scale ->  0 | Confidence Score [259.60189577]
#
# Detection:: Location -> (60, 12)
# Scale ->  0 | Confidence Score [109.2343482]
#
# Detection:: Location -> (72, 12)
# Scale ->  0 | Confidence Score [59.5389266]
#
# Detection:: Location -> (84, 12)
# Scale ->  0 | Confidence Score [47.42340076]
#
# Detection:: Location -> (96, 12)
# Scale ->  0 | Confidence Score [271.97911455]
#
# Detection:: Location -> (108, 12)
# Scale ->  0 | Confidence Score [0.45029231]
#
# Detection:: Location -> (120, 12)
# Scale ->  0 | Confidence Score [42.90373361]
#
# Detection:: Location -> (144, 12)
# Scale ->  0 | Confidence Score [243.02107369]
#
# Detection:: Location -> (156, 12)
# Scale ->  0 | Confidence Score [167.03934938]
#
# Detection:: Location -> (168, 12)
# Scale ->  0 | Confidence Score [279.9649102]
#
# Detection:: Location -> (180, 12)
# Scale ->  0 | Confidence Score [122.00602789]
#
# Detection:: Location -> (192, 12)
# Scale ->  0 | Confidence Score [180.14493464]
#
# Detection:: Location -> (204, 12)
# Scale ->  0 | Confidence Score [53.5182109]
#
# Detection:: Location -> (216, 12)
# Scale ->  0 | Confidence Score [167.63115888]
#
# Detection:: Location -> (228, 12)
# Scale ->  0 | Confidence Score [166.10913247]
#
# Detection:: Location -> (240, 12)
# Scale ->  0 | Confidence Score [163.33832355]
#
# Detection:: Location -> (252, 12)
# Scale ->  0 | Confidence Score [54.47988564]
#
# Detection:: Location -> (264, 12)
# Scale ->  0 | Confidence Score [26.25056508]
#
# Detection:: Location -> (276, 12)
# Scale ->  0 | Confidence Score [40.07954243]
#
# Detection:: Location -> (36, 24)
# Scale ->  0 | Confidence Score [176.0345345]
#
# Detection:: Location -> (48, 24)
# Scale ->  0 | Confidence Score [233.84591339]
#
# Detection:: Location -> (60, 24)
# Scale ->  0 | Confidence Score [132.44264026]
#
# Detection:: Location -> (72, 24)
# Scale ->  0 | Confidence Score [18.5015139]
#
# Detection:: Location -> (84, 24)
# Scale ->  0 | Confidence Score [44.47282586]
#
# Detection:: Location -> (96, 24)
# Scale ->  0 | Confidence Score [364.4528809]
#
# Detection:: Location -> (144, 24)
# Scale ->  0 | Confidence Score [208.5539034]
#
# Detection:: Location -> (156, 24)
# Scale ->  0 | Confidence Score [11.47177656]
#
# Detection:: Location -> (180, 24)
# Scale ->  0 | Confidence Score [99.89207273]
#
# Detection:: Location -> (192, 24)
# Scale ->  0 | Confidence Score [131.92241008]
#
# Detection:: Location -> (204, 24)
# Scale ->  0 | Confidence Score [5.20747003]
#
# Detection:: Location -> (216, 24)
# Scale ->  0 | Confidence Score [146.86008743]
#
# Detection:: Location -> (228, 24)
# Scale ->  0 | Confidence Score [68.7914917]
#
# Detection:: Location -> (240, 24)
# Scale ->  0 | Confidence Score [43.22769028]
#
# Detection:: Location -> (252, 24)
# Scale ->  0 | Confidence Score [75.18315627]
#
# Detection:: Location -> (264, 24)
# Scale ->  0 | Confidence Score [34.0931493]
#
# Detection:: Location -> (276, 24)
# Scale ->  0 | Confidence Score [50.17569536]
#
# Detection:: Location -> (0, 36)
# Scale ->  0 | Confidence Score [50.50671074]
#
# Detection:: Location -> (36, 36)
# Scale ->  0 | Confidence Score [230.61130198]
#
# Detection:: Location -> (48, 36)
# Scale ->  0 | Confidence Score [277.6327895]
#
# Detection:: Location -> (60, 36)
# Scale ->  0 | Confidence Score [91.67343907]
#
# Detection:: Location -> (72, 36)
# Scale ->  0 | Confidence Score [12.16475726]
#
# Detection:: Location -> (84, 36)
# Scale ->  0 | Confidence Score [74.73603957]
#
# Detection:: Location -> (96, 36)
# Scale ->  0 | Confidence Score [332.60531942]
#
# Detection:: Location -> (144, 36)
# Scale ->  0 | Confidence Score [103.90843639]
#
# Detection:: Location -> (192, 36)
# Scale ->  0 | Confidence Score [117.04981587]
#
# Detection:: Location -> (204, 36)
# Scale ->  0 | Confidence Score [93.27406331]
#
# Detection:: Location -> (216, 36)
# Scale ->  0 | Confidence Score [80.61191686]
#
# Detection:: Location -> (228, 36)
# Scale ->  0 | Confidence Score [65.36279051]
#
# Detection:: Location -> (240, 36)
# Scale ->  0 | Confidence Score [104.78010176]
#
# Detection:: Location -> (252, 36)
# Scale ->  0 | Confidence Score [116.22012292]
#
# Detection:: Location -> (264, 36)
# Scale ->  0 | Confidence Score [80.50351187]
#
# Detection:: Location -> (276, 36)
# Scale ->  0 | Confidence Score [100.08349942]
#
# Detection:: Location -> (36, 48)
# Scale ->  0 | Confidence Score [243.6185141]
#
# Detection:: Location -> (48, 48)
# Scale ->  0 | Confidence Score [311.87838554]
#
# Detection:: Location -> (60, 48)
# Scale ->  0 | Confidence Score [154.15764876]
#
# Detection:: Location -> (72, 48)
# Scale ->  0 | Confidence Score [16.14015689]
#
# Detection:: Location -> (84, 48)
# Scale ->  0 | Confidence Score [27.9403473]
#
# Detection:: Location -> (96, 48)
# Scale ->  0 | Confidence Score [338.30869127]
#
# Detection:: Location -> (132, 48)
# Scale ->  0 | Confidence Score [46.88603271]
#
# Detection:: Location -> (144, 48)
# Scale ->  0 | Confidence Score [268.74345468]
#
# Detection:: Location -> (156, 48)
# Scale ->  0 | Confidence Score [87.53386336]
#
# Detection:: Location -> (168, 48)
# Scale ->  0 | Confidence Score [40.94305613]
#
# Detection:: Location -> (180, 48)
# Scale ->  0 | Confidence Score [18.4959621]
#
# Detection:: Location -> (204, 48)
# Scale ->  0 | Confidence Score [125.70737233]
#
# Detection:: Location -> (216, 48)
# Scale ->  0 | Confidence Score [85.11901253]
#
# Detection:: Location -> (228, 48)
# Scale ->  0 | Confidence Score [62.09707809]
#
# Detection:: Location -> (240, 48)
# Scale ->  0 | Confidence Score [59.92746684]
#
# Detection:: Location -> (252, 48)
# Scale ->  0 | Confidence Score [186.73681862]
#
# Detection:: Location -> (264, 48)
# Scale ->  0 | Confidence Score [53.33352561]
#
# Detection:: Location -> (276, 48)
# Scale ->  0 | Confidence Score [86.52711429]
#
# Detection:: Location -> (0, 60)
# Scale ->  0 | Confidence Score [32.52609374]
#
# Detection:: Location -> (36, 60)
# Scale ->  0 | Confidence Score [233.15904476]
#
# Detection:: Location -> (48, 60)
# Scale ->  0 | Confidence Score [290.1034044]
#
# Detection:: Location -> (60, 60)
# Scale ->  0 | Confidence Score [122.40156997]
#
# Detection:: Location -> (84, 60)
# Scale ->  0 | Confidence Score [131.41432678]
#
# Detection:: Location -> (96, 60)
# Scale ->  0 | Confidence Score [261.08622049]
#
# Detection:: Location -> (108, 60)
# Scale ->  0 | Confidence Score [73.76451746]
#
# Detection:: Location -> (120, 60)
# Scale ->  0 | Confidence Score [49.38695046]
#
# Detection:: Location -> (132, 60)
# Scale ->  0 | Confidence Score [89.33582185]
#
# Detection:: Location -> (144, 60)
# Scale ->  0 | Confidence Score [277.39508323]
#
# Detection:: Location -> (156, 60)
# Scale ->  0 | Confidence Score [193.05778383]
#
# Detection:: Location -> (168, 60)
# Scale ->  0 | Confidence Score [56.46452386]
#
# Detection:: Location -> (180, 60)
# Scale ->  0 | Confidence Score [113.91700649]
#
# Detection:: Location -> (192, 60)
# Scale ->  0 | Confidence Score [84.40107292]
#
# Detection:: Location -> (204, 60)
# Scale ->  0 | Confidence Score [86.49184102]
#
# Detection:: Location -> (216, 60)
# Scale ->  0 | Confidence Score [2.34575704]
#
# Detection:: Location -> (228, 60)
# Scale ->  0 | Confidence Score [17.60025182]
#
# Detection:: Location -> (240, 60)
# Scale ->  0 | Confidence Score [35.09222361]
#
# Detection:: Location -> (252, 60)
# Scale ->  0 | Confidence Score [9.08453558]
#
# Detection:: Location -> (264, 60)
# Scale ->  0 | Confidence Score [58.41250212]
#
# Detection:: Location -> (36, 72)
# Scale ->  0 | Confidence Score [231.82030529]
#
# Detection:: Location -> (48, 72)
# Scale ->  0 | Confidence Score [236.4261315]
#
# Detection:: Location -> (60, 72)
# Scale ->  0 | Confidence Score [212.41145073]
#
# Detection:: Location -> (96, 72)
# Scale ->  0 | Confidence Score [146.56993811]
#
# Detection:: Location -> (108, 72)
# Scale ->  0 | Confidence Score [64.46590256]
#
# Detection:: Location -> (120, 72)
# Scale ->  0 | Confidence Score [4.50052644]
#
# Detection:: Location -> (132, 72)
# Scale ->  0 | Confidence Score [15.26155017]
#
# Detection:: Location -> (144, 72)
# Scale ->  0 | Confidence Score [118.22870114]
#
# Detection:: Location -> (156, 72)
# Scale ->  0 | Confidence Score [64.52707853]
#
# Detection:: Location -> (168, 72)
# Scale ->  0 | Confidence Score [123.44537864]
# Detection:: Location -> (180, 72)
# Scale ->  0 | Confidence Score [148.37869715]
#
# Detection:: Location -> (192, 72)
# Scale ->  0 | Confidence Score [63.09895253]
#
# Detection:: Location -> (204, 72)
# Scale ->  0 | Confidence Score [91.43987981]
#
# Detection:: Location -> (228, 72)
# Scale ->  0 | Confidence Score [29.78319362]
#
# Detection:: Location -> (240, 72)
# Scale ->  0 | Confidence Score [66.40461838]
#
# Detection:: Location -> (252, 72)
# Scale ->  0 | Confidence Score [9.72034023]
#
# Detection:: Location -> (264, 72)
# Scale ->  0 | Confidence Score [89.44208244]
#
# Detection:: Location -> (276, 72)
# Scale ->  0 | Confidence Score [82.28378971]
#
# Detection:: Location -> (36, 84)
# Scale ->  0 | Confidence Score [250.34059294]
#
# Detection:: Location -> (48, 84)
# Scale ->  0 | Confidence Score [235.06284503]
#
# Detection:: Location -> (60, 84)
# Scale ->  0 | Confidence Score [131.46730822]
#
# Detection:: Location -> (72, 84)
# Scale ->  0 | Confidence Score [30.85940818]
#
# Detection:: Location -> (96, 84)
# Scale ->  0 | Confidence Score [178.80323873]
#
# Detection:: Location -> (108, 84)
# Scale ->  0 | Confidence Score [98.53558359]
#
# Detection:: Location -> (120, 84)
# Scale ->  0 | Confidence Score [94.00913697]
#
# Detection:: Location -> (132, 84)
# Scale ->  0 | Confidence Score [14.55306692]
#
# Detection:: Location -> (144, 84)
# Scale ->  0 | Confidence Score [78.56064992]
#
# Detection:: Location -> (156, 84)
# Scale ->  0 | Confidence Score [129.25815557]
#
# Detection:: Location -> (168, 84)
# Scale ->  0 | Confidence Score [116.88156877]
#
# Detection:: Location -> (180, 84)
# Scale ->  0 | Confidence Score [100.1474389]
#
# Detection:: Location -> (192, 84)
# Scale ->  0 | Confidence Score [93.75513957]
#
# Detection:: Location -> (204, 84)
# Scale ->  0 | Confidence Score [98.26658832]
#
# Detection:: Location -> (216, 84)
# Scale ->  0 | Confidence Score [90.40721733]
#
# Detection:: Location -> (228, 84)
# Scale ->  0 | Confidence Score [24.58131827]
#
# Detection:: Location -> (240, 84)
# Scale ->  0 | Confidence Score [27.1034544]
#
# Detection:: Location -> (276, 84)
# Scale ->  0 | Confidence Score [160.26487934]
#
# Detection:: Location -> (0, 96)
# Scale ->  0 | Confidence Score [29.05352243]
#
# Detection:: Location -> (36, 96)
# Scale ->  0 | Confidence Score [262.03069376]
#
# Detection:: Location -> (48, 96)
# Scale ->  0 | Confidence Score [236.11108645]
#
# Detection:: Location -> (60, 96)
# Scale ->  0 | Confidence Score [192.38164059]
#
# Detection:: Location -> (72, 96)
# Scale ->  0 | Confidence Score [62.30812206]
#
# Detection:: Location -> (84, 96)
# Scale ->  0 | Confidence Score [82.91785508]
#
# Detection:: Location -> (96, 96)
# Scale ->  0 | Confidence Score [75.57189273]
#
# Detection:: Location -> (108, 96)
# Scale ->  0 | Confidence Score [8.55840825]
#
# Detection:: Location -> (120, 96)
# Scale ->  0 | Confidence Score [19.93733366]
#
# Detection:: Location -> (132, 96)
# Scale ->  0 | Confidence Score [13.4393791]
#
# Detection:: Location -> (144, 96)
# Scale ->  0 | Confidence Score [173.27642885]
#
# Detection:: Location -> (156, 96)
# Scale ->  0 | Confidence Score [127.76049533]
#
# Detection:: Location -> (168, 96)
# Scale ->  0 | Confidence Score [89.03801024]
#
# Detection:: Location -> (180, 96)
# Scale ->  0 | Confidence Score [47.2722896]
#
# Detection:: Location -> (204, 96)
# Scale ->  0 | Confidence Score [163.49594833]
#
# Detection:: Location -> (216, 96)
# Scale ->  0 | Confidence Score [30.04462233]
#
# Detection:: Location -> (228, 96)
# Scale ->  0 | Confidence Score [78.02303094]
#
# Detection:: Location -> (240, 96)
# Scale ->  0 | Confidence Score [37.48671873]
#
# Detection:: Location -> (252, 96)
# Scale ->  0 | Confidence Score [139.49723869]
#
# Detection:: Location -> (264, 96)
# Scale ->  0 | Confidence Score [113.35872687]
#
# Detection:: Location -> (276, 96)
# Scale ->  0 | Confidence Score [134.71289165]
#
# Detection:: Location -> (36, 108)
# Scale ->  0 | Confidence Score [216.71360334]
#
# Detection:: Location -> (48, 108)
# Scale ->  0 | Confidence Score [127.79847924]
#
# Detection:: Location -> (60, 108)
# Scale ->  0 | Confidence Score [223.01244594]
#
# Detection:: Location -> (72, 108)
# Scale ->  0 | Confidence Score [58.64065062]
#
# Detection:: Location -> (84, 108)
# Scale ->  0 | Confidence Score [216.4947901]
#
# Detection:: Location -> (96, 108)
# Scale ->  0 | Confidence Score [21.66990305]
#
# Detection:: Location -> (108, 108)
# Scale ->  0 | Confidence Score [63.56504657]
#
# Detection:: Location -> (120, 108)
# Scale ->  0 | Confidence Score [68.34038587]
#
# Detection:: Location -> (132, 108)
# Scale ->  0 | Confidence Score [21.85502099]
#
# Detection:: Location -> (144, 108)
# Scale ->  0 | Confidence Score [175.15486082]
#
# Detection:: Location -> (156, 108)
# Scale ->  0 | Confidence Score [29.29408809]
#
# Detection:: Location -> (168, 108)
# Scale ->  0 | Confidence Score [138.13156387]
#
# Detection:: Location -> (180, 108)
# Scale ->  0 | Confidence Score [152.7133996]
#
# Detection:: Location -> (192, 108)
# Scale ->  0 | Confidence Score [104.0263412]
#
# Detection:: Location -> (204, 108)
# Scale ->  0 | Confidence Score [123.13640285]
#
# Detection:: Location -> (216, 108)
# Scale ->  0 | Confidence Score [5.33192368]
#
# Detection:: Location -> (228, 108)
# Scale ->  0 | Confidence Score [30.33565205]
#
# Detection:: Location -> (240, 108)
# Scale ->  0 | Confidence Score [80.00996333]
#
# Detection:: Location -> (252, 108)
# Scale ->  0 | Confidence Score [79.65888854]
#
# Detection:: Location -> (264, 108)
# Scale ->  0 | Confidence Score [69.11741679]
#
# Detection:: Location -> (276, 108)
# Scale ->  0 | Confidence Score [111.25018879]
#
# Detection:: Location -> (36, 120)
# Scale ->  0 | Confidence Score [292.72259436]
#
# Detection:: Location -> (48, 120)
# Scale ->  0 | Confidence Score [130.62744497]
#
# Detection:: Location -> (60, 120)
# Scale ->  0 | Confidence Score [143.75781467]
#
# Detection:: Location -> (72, 120)
# Scale ->  0 | Confidence Score [232.07944079]
#
# Detection:: Location -> (84, 120)
# Scale ->  0 | Confidence Score [250.47148559]
#
# Detection:: Location -> (96, 120)
# Scale ->  0 | Confidence Score [81.29339139]
#
# Detection:: Location -> (108, 120)
# Scale ->  0 | Confidence Score [50.30682683]
#
# Detection:: Location -> (120, 120)
# Scale ->  0 | Confidence Score [6.8967132]
#
# Detection:: Location -> (144, 120)
# Scale ->  0 | Confidence Score [193.66594933]
#
# Detection:: Location -> (156, 120)
# Scale ->  0 | Confidence Score [46.90391205]
#
# Detection:: Location -> (180, 120)
# Scale ->  0 | Confidence Score [74.18847268]
#
# Detection:: Location -> (192, 120)
# Scale ->  0 | Confidence Score [85.03276339]
#
# Detection:: Location -> (204, 120)
# Scale ->  0 | Confidence Score [64.53982475]
#
# Detection:: Location -> (228, 120)
# Scale ->  0 | Confidence Score [55.27697121]
#
# Detection:: Location -> (240, 120)
# Scale ->  0 | Confidence Score [38.10871216]
#
# Detection:: Location -> (252, 120)
# Scale ->  0 | Confidence Score [99.52961364]
#
# Detection:: Location -> (264, 120)
# Scale ->  0 | Confidence Score [89.08192783]
#
# Detection:: Location -> (276, 120)
# Scale ->  0 | Confidence Score [53.24583053]
#
# Detection:: Location -> (36, 132)
# Scale ->  0 | Confidence Score [225.07073975]
#
# Detection:: Location -> (48, 132)
# Scale ->  0 | Confidence Score [140.50728212]
#
# Detection:: Location -> (60, 132)
# Scale ->  0 | Confidence Score [134.13771484]
#
# Detection:: Location -> (72, 132)
# Scale ->  0 | Confidence Score [168.01061778]
#
# Detection:: Location -> (84, 132)
# Scale ->  0 | Confidence Score [134.68865263]
#
# Detection:: Location -> (96, 132)
# Scale ->  0 | Confidence Score [72.67558737]
#
# Detection:: Location -> (108, 132)
# Scale ->  0 | Confidence Score [47.58621314]
#
# Detection:: Location -> (120, 132)
# Scale ->  0 | Confidence Score [83.69292957]
#
# Detection:: Location -> (132, 132)
# Scale ->  0 | Confidence Score [25.21844718]
#
# Detection:: Location -> (144, 132)
# Scale ->  0 | Confidence Score [160.94918799]
#
# Detection:: Location -> (156, 132)
# Scale ->  0 | Confidence Score [47.06804065]
#
# Detection:: Location -> (168, 132)
# Scale ->  0 | Confidence Score [69.99756589]
#
# Detection:: Location -> (180, 132)
# Scale ->  0 | Confidence Score [69.85638184]
#
# Detection:: Location -> (192, 132)
# Scale ->  0 | Confidence Score [127.53916227]
#
# Detection:: Location -> (204, 132)
# Scale ->  0 | Confidence Score [53.54345786]
#
# Detection:: Location -> (216, 132)
# Scale ->  0 | Confidence Score [68.51120494]
#
# Detection:: Location -> (228, 132)
# Scale ->  0 | Confidence Score [143.88770999]
#
# Detection:: Location -> (240, 132)
# Scale ->  0 | Confidence Score [88.3579781]
#
# Detection:: Location -> (252, 132)
# Scale ->  0 | Confidence Score [23.40900212]
#
# Detection:: Location -> (264, 132)
# Scale ->  0 | Confidence Score [61.86866383]
#
# Detection:: Location -> (276, 132)
# Scale ->  0 | Confidence Score [115.3424305]
#
# Detection:: Location -> (0, 144)
# Scale ->  0 | Confidence Score [38.02919697]
#
# Detection:: Location -> (36, 144)
# Scale ->  0 | Confidence Score [354.44368443]
#
# Detection:: Location -> (48, 144)
# Scale ->  0 | Confidence Score [169.6375238]
#
# Detection:: Location -> (60, 144)
# Scale ->  0 | Confidence Score [123.45341178]
#
# Detection:: Location -> (72, 144)
# Scale ->  0 | Confidence Score [160.25185428]
#
# Detection:: Location -> (84, 144)
# Scale ->  0 | Confidence Score [192.21968436]
#
# Detection:: Location -> (96, 144)
# Scale ->  0 | Confidence Score [106.65705598]
#
# Detection:: Location -> (108, 144)
# Scale ->  0 | Confidence Score [105.99582657]
#
# Detection:: Location -> (120, 144)
# Scale ->  0 | Confidence Score [156.6260805]
#
# Detection:: Location -> (132, 144)
# Scale ->  0 | Confidence Score [12.64940697]
#
# Detection:: Location -> (144, 144)
# Scale ->  0 | Confidence Score [232.34179844]
#
# Detection:: Location -> (156, 144)
# Scale ->  0 | Confidence Score [146.98856884]
#
# Detection:: Location -> (168, 144)
# Scale ->  0 | Confidence Score [82.78396345]
#
# Detection:: Location -> (180, 144)
# Scale ->  0 | Confidence Score [27.72313239]
#
# Detection:: Location -> (192, 144)
# Scale ->  0 | Confidence Score [108.23931429]
#
# Detection:: Location -> (204, 144)
# Scale ->  0 | Confidence Score [120.41218718]
#
# Detection:: Location -> (216, 144)
# Scale ->  0 | Confidence Score [73.94890284]
#
# Detection:: Location -> (228, 144)
# Scale ->  0 | Confidence Score [101.70762097]
#
# Detection:: Location -> (240, 144)
# Scale ->  0 | Confidence Score [31.76851271]
#
# Detection:: Location -> (252, 144)
# Scale ->  0 | Confidence Score [54.57469826]
#
# Detection:: Location -> (264, 144)
# Scale ->  0 | Confidence Score [81.57904729]
#
# Detection:: Location -> (276, 144)
# Scale ->  0 | Confidence Score [71.62685699]
#
# Detection:: Location -> (36, 156)
# Scale ->  0 | Confidence Score [379.16026143]
#
# Detection:: Location -> (48, 156)
# Scale ->  0 | Confidence Score [301.75906367]
#
# Detection:: Location -> (60, 156)
# Scale ->  0 | Confidence Score [78.21020933]
#
# Detection:: Location -> (72, 156)
# Scale ->  0 | Confidence Score [108.63264436]
#
# Detection:: Location -> (84, 156)
# Scale ->  0 | Confidence Score [147.73304817]
#
# Detection:: Location -> (96, 156)
# Scale ->  0 | Confidence Score [195.55615955]
#
# Detection:: Location -> (108, 156)
# Scale ->  0 | Confidence Score [28.77697546]
#
# Detection:: Location -> (120, 156)
# Scale ->  0 | Confidence Score [122.80442683]
#
# Detection:: Location -> (132, 156)
# Scale ->  0 | Confidence Score [17.61830019]
#
# Detection:: Location -> (144, 156)
# Scale ->  0 | Confidence Score [137.74189066]
#
# Detection:: Location -> (168, 156)
# Scale ->  0 | Confidence Score [163.58178532]
#
# Detection:: Location -> (180, 156)
# Scale ->  0 | Confidence Score [60.70015979]
#
# Detection:: Location -> (192, 156)
# Scale ->  0 | Confidence Score [118.34454051]
#
# Detection:: Location -> (204, 156)
# Scale ->  0 | Confidence Score [95.04268386]
#
# Detection:: Location -> (216, 156)
# Scale ->  0 | Confidence Score [57.52305848]
#
# Detection:: Location -> (228, 156)
# Scale ->  0 | Confidence Score [21.21517619]
#
# Detection:: Location -> (240, 156)
# Scale ->  0 | Confidence Score [116.64333164]
#
# Detection:: Location -> (252, 156)
# Scale ->  0 | Confidence Score [7.83490185]
#
# Detection:: Location -> (264, 156)
# Scale ->  0 | Confidence Score [25.00696367]
#
# Detection:: Location -> (276, 156)
# Scale ->  0 | Confidence Score [45.57161179]
#
# Detection:: Location -> (0, 168)
# Scale ->  0 | Confidence Score [22.27344248]
#
# Detection:: Location -> (36, 168)
# Scale ->  0 | Confidence Score [243.32342811]
#
# Detection:: Location -> (48, 168)
# Scale ->  0 | Confidence Score [333.15890577]
#
# Detection:: Location -> (60, 168)
# Scale ->  0 | Confidence Score [102.01163753]
#
# Detection:: Location -> (72, 168)
# Scale ->  0 | Confidence Score [88.75528143]
#
# Detection:: Location -> (84, 168)
# Scale ->  0 | Confidence Score [243.59762873]
#
# Detection:: Location -> (96, 168)
# Scale ->  0 | Confidence Score [237.03924824]
#
# Detection:: Location -> (120, 168)
# Scale ->  0 | Confidence Score [150.35090604]
#
# Detection:: Location -> (144, 168)
# Scale ->  0 | Confidence Score [5.23300237]
#
# Detection:: Location -> (156, 168)
# Scale ->  0 | Confidence Score [39.18884507]
#
# Detection:: Location -> (168, 168)
# Scale ->  0 | Confidence Score [74.06648213]
#
# Detection:: Location -> (192, 168)
# Scale ->  0 | Confidence Score [84.78241972]
#
# Detection:: Location -> (216, 168)
# Scale ->  0 | Confidence Score [24.90000789]
#
# Detection:: Location -> (228, 168)
# Scale ->  0 | Confidence Score [66.96098277]
#
# Detection:: Location -> (240, 168)
# Scale ->  0 | Confidence Score [87.06294448]
#
# Detection:: Location -> (252, 168)
# Scale ->  0 | Confidence Score [71.68447148]
#
# Detection:: Location -> (264, 168)
# Scale ->  0 | Confidence Score [117.76098514]
#
# Detection:: Location -> (276, 168)
# Scale ->  0 | Confidence Score [110.72336153]
#
# Detection:: Location -> (0, 180)
# Scale ->  0 | Confidence Score [125.44755364]
#
# Detection:: Location -> (36, 180)
# Scale ->  0 | Confidence Score [254.27448899]
#
# Detection:: Location -> (48, 180)
# Scale ->  0 | Confidence Score [270.14224046]
#
# Detection:: Location -> (72, 180)
# Scale ->  0 | Confidence Score [193.69302222]
#
# Detection:: Location -> (84, 180)
# Scale ->  0 | Confidence Score [41.56786994]
#
# Detection:: Location -> (96, 180)
# Scale ->  0 | Confidence Score [299.38513294]
#
# Detection:: Location -> (120, 180)
# Scale ->  0 | Confidence Score [207.70560653]
#
# Detection:: Location -> (144, 180)
# Scale ->  0 | Confidence Score [112.51505771]
#
# Detection:: Location -> (168, 180)
# Scale ->  0 | Confidence Score [60.01971358]
#
# Detection:: Location -> (180, 180)
# Scale ->  0 | Confidence Score [41.86687902]
#
# Detection:: Location -> (192, 180)
# Scale ->  0 | Confidence Score [56.90719072]
#
# Detection:: Location -> (204, 180)
# Scale ->  0 | Confidence Score [39.2940976]
#
# Detection:: Location -> (216, 180)
# Scale ->  0 | Confidence Score [70.79647136]
#
# Detection:: Location -> (228, 180)
# Scale ->  0 | Confidence Score [90.584722]
#
# Detection:: Location -> (240, 180)
# Scale ->  0 | Confidence Score [133.87141797]
#
# Detection:: Location -> (252, 180)
# Scale ->  0 | Confidence Score [143.77075118]
#
# Detection:: Location -> (264, 180)
# Scale ->  0 | Confidence Score [136.00024359]
#
# Detection:: Location -> (276, 180)
# Scale ->  0 | Confidence Score [94.02493324]
#
# Detection:: Location -> (0, 192)
# Scale ->  0 | Confidence Score [51.21844557]
#
# Detection:: Location -> (36, 192)
# Scale ->  0 | Confidence Score [222.00514706]
#
# Detection:: Location -> (48, 192)
# Scale ->  0 | Confidence Score [238.58257365]
#
# Detection:: Location -> (60, 192)
# Scale ->  0 | Confidence Score [13.54764602]
#
# Detection:: Location -> (72, 192)
# Scale ->  0 | Confidence Score [143.6945088]
#
# Detection:: Location -> (96, 192)
# Scale ->  0 | Confidence Score [280.08916636]
#
# Detection:: Location -> (108, 192)
# Scale ->  0 | Confidence Score [33.02409338]
#
# Detection:: Location -> (120, 192)
# Scale ->  0 | Confidence Score [245.49437497]
#
# Detection:: Location -> (144, 192)
# Scale ->  0 | Confidence Score [137.43418251]
#
# Detection:: Location -> (156, 192)
# Scale ->  0 | Confidence Score [53.04994463]
#
# Detection:: Location -> (168, 192)
# Scale ->  0 | Confidence Score [154.73035414]
#
# Detection:: Location -> (192, 192)
# Scale ->  0 | Confidence Score [9.56361226]
#
# Detection:: Location -> (204, 192)
# Scale ->  0 | Confidence Score [78.24721931]
#
# Detection:: Location -> (216, 192)
# Scale ->  0 | Confidence Score [104.99906427]
#
# Detection:: Location -> (228, 192)
# Scale ->  0 | Confidence Score [89.41339482]
#
# Detection:: Location -> (240, 192)
# Scale ->  0 | Confidence Score [125.12738399]
#
# Detection:: Location -> (252, 192)
# Scale ->  0 | Confidence Score [46.78340904]
#
# Detection:: Location -> (264, 192)
# Scale ->  0 | Confidence Score [97.9495176]
#
# Detection:: Location -> (276, 192)
# Scale ->  0 | Confidence Score [88.94884419]
#
# Detection:: Location -> (24, 0)
# Scale ->  1 | Confidence Score [238.45958166]
#
# Detection:: Location -> (48, 0)
# Scale ->  1 | Confidence Score [28.31957366]
#
# Detection:: Location -> (72, 0)
# Scale ->  1 | Confidence Score [246.52355062]
#
# Detection:: Location -> (84, 0)
# Scale ->  1 | Confidence Score [119.83767475]
#
# Detection:: Location -> (108, 0)
# Scale ->  1 | Confidence Score [194.21673992]
#
# Detection:: Location -> (120, 0)
# Scale ->  1 | Confidence Score [188.3902125]
#
# Detection:: Location -> (132, 0)
# Scale ->  1 | Confidence Score [274.60349888]
#
# Detection:: Location -> (144, 0)
# Scale ->  1 | Confidence Score [221.34820402]
#
# Detection:: Location -> (156, 0)
# Scale ->  1 | Confidence Score [72.3318855]
#
# Detection:: Location -> (168, 0)
# Scale ->  1 | Confidence Score [29.49692145]
#
# Detection:: Location -> (180, 0)
# Scale ->  1 | Confidence Score [63.95115754]
#
# Detection:: Location -> (192, 0)
# Scale ->  1 | Confidence Score [40.54515183]
#
# Detection:: Location -> (204, 0)
# Scale ->  1 | Confidence Score [87.35470636]
#
# Detection:: Location -> (24, 12)
# Scale ->  1 | Confidence Score [325.56979769]
#
# Detection:: Location -> (36, 12)
# Scale ->  1 | Confidence Score [54.64751566]
#
# Detection:: Location -> (72, 12)
# Scale ->  1 | Confidence Score [239.85255408]
#
# Detection:: Location -> (96, 12)
# Scale ->  1 | Confidence Score [26.65807727]
#
# Detection:: Location -> (108, 12)
# Scale ->  1 | Confidence Score [168.9682754]
#
# Detection:: Location -> (120, 12)
# Scale ->  1 | Confidence Score [132.77771513]
#
# Detection:: Location -> (132, 12)
# Scale ->  1 | Confidence Score [23.14055895]
#
# Detection:: Location -> (144, 12)
# Scale ->  1 | Confidence Score [181.3256542]
#
# Detection:: Location -> (156, 12)
# Scale ->  1 | Confidence Score [101.1019842]
#
# Detection:: Location -> (168, 12)
# Scale ->  1 | Confidence Score [84.22922494]
#
# Detection:: Location -> (180, 12)
# Scale ->  1 | Confidence Score [88.22856446]
#
# Detection:: Location -> (192, 12)
# Scale ->  1 | Confidence Score [57.91159761]
#
# Detection:: Location -> (204, 12)
# Scale ->  1 | Confidence Score [35.41010684]
#
# Detection:: Location -> (24, 24)
# Scale ->  1 | Confidence Score [270.55028829]
#
# Detection:: Location -> (36, 24)
# Scale ->  1 | Confidence Score [32.49774882]
#
# Detection:: Location -> (48, 24)
# Scale ->  1 | Confidence Score [43.02618969]
#
# Detection:: Location -> (72, 24)
# Scale ->  1 | Confidence Score [251.23351495]
#
# Detection:: Location -> (84, 24)
# Scale ->  1 | Confidence Score [2.20638966]
#
# Detection:: Location -> (96, 24)
# Scale ->  1 | Confidence Score [12.71798326]
#
# Detection:: Location -> (108, 24)
# Scale ->  1 | Confidence Score [208.75114352]
#
# Detection:: Location -> (120, 24)
# Scale ->  1 | Confidence Score [155.79131565]
#
# Detection:: Location -> (144, 24)
# Scale ->  1 | Confidence Score [81.06775954]
#
# Detection:: Location -> (156, 24)
# Scale ->  1 | Confidence Score [71.10490624]
#
# Detection:: Location -> (168, 24)
# Scale ->  1 | Confidence Score [85.42513704]
#
# Detection:: Location -> (180, 24)
# Scale ->  1 | Confidence Score [64.08064414]
#
# Detection:: Location -> (192, 24)
# Scale ->  1 | Confidence Score [90.99102039]
#
# Detection:: Location -> (24, 36)
# Scale ->  1 | Confidence Score [331.37277026]
#
# Detection:: Location -> (36, 36)
# Scale ->  1 | Confidence Score [198.97492158]
#
# Detection:: Location -> (48, 36)
# Scale ->  1 | Confidence Score [15.39130931]
#
# Detection:: Location -> (72, 36)
# Scale ->  1 | Confidence Score [96.41342392]
#
# Detection:: Location -> (84, 36)
# Scale ->  1 | Confidence Score [23.35278326]
#
# Detection:: Location -> (96, 36)
# Scale ->  1 | Confidence Score [67.20157788]
#
# Detection:: Location -> (108, 36)
# Scale ->  1 | Confidence Score [148.24735303]
#
# Detection:: Location -> (120, 36)
# Scale ->  1 | Confidence Score [208.19969233]
#
# Detection:: Location -> (132, 36)
# Scale ->  1 | Confidence Score [1.00517493]
# /Users/miracle/anaconda2/envs/py3/lib/python3.6/site-packages/skimage/transform/_warps.py:24: UserWarning: The default multichannel argument (None) is deprecated.  Please specify either True or False explicitly.  multichannel will default to False starting with release 0.16.
#   warn('The default multichannel argument (None) is deprecated.  Please '
# Detection:: Location -> (144, 36)
# Scale ->  1 | Confidence Score [57.67057211]
#
# Detection:: Location -> (156, 36)
# Scale ->  1 | Confidence Score [106.70290519]
#
# Detection:: Location -> (180, 36)
# Scale ->  1 | Confidence Score [102.47960861]
#
# Detection:: Location -> (192, 36)
# Scale ->  1 | Confidence Score [47.17969895]
#
# Detection:: Location -> (204, 36)
# Scale ->  1 | Confidence Score [59.94800363]
#
# Detection:: Location -> (0, 48)
# Scale ->  1 | Confidence Score [24.73812745]
#
# Detection:: Location -> (24, 48)
# Scale ->  1 | Confidence Score [374.90261601]
#
# Detection:: Location -> (36, 48)
# Scale ->  1 | Confidence Score [184.40251271]
#
# Detection:: Location -> (48, 48)
# Scale ->  1 | Confidence Score [8.80544302]
#
# Detection:: Location -> (72, 48)
# Scale ->  1 | Confidence Score [141.83303034]
#
# Detection:: Location -> (84, 48)
# Scale ->  1 | Confidence Score [155.01768751]
#
# Detection:: Location -> (108, 48)
# Scale ->  1 | Confidence Score [157.49110878]
#
# Detection:: Location -> (120, 48)
# Scale ->  1 | Confidence Score [147.18677617]
#
# Detection:: Location -> (132, 48)
# Scale ->  1 | Confidence Score [105.00784047]
#
# Detection:: Location -> (144, 48)
# Scale ->  1 | Confidence Score [115.57570869]
#
# Detection:: Location -> (156, 48)
# Scale ->  1 | Confidence Score [89.70064902]
#
# Detection:: Location -> (168, 48)
# Scale ->  1 | Confidence Score [75.49838436]
#
# Detection:: Location -> (180, 48)
# Scale ->  1 | Confidence Score [36.08989791]
#
# Detection:: Location -> (192, 48)
# Scale ->  1 | Confidence Score [168.81983464]
#
# Detection:: Location -> (204, 48)
# Scale ->  1 | Confidence Score [61.47879304]
#
# Detection:: Location -> (24, 60)
# Scale ->  1 | Confidence Score [294.86458311]
#
# Detection:: Location -> (36, 60)
# Scale ->  1 | Confidence Score [184.23254416]
#
# Detection:: Location -> (72, 60)
# Scale ->  1 | Confidence Score [141.70837069]
#
# Detection:: Location -> (84, 60)
# Scale ->  1 | Confidence Score [100.6920545]
#
# Detection:: Location -> (96, 60)
# Scale ->  1 | Confidence Score [96.27027925]
#
# Detection:: Location -> (108, 60)
# Scale ->  1 | Confidence Score [1.96909224]
#
# Detection:: Location -> (120, 60)
# Scale ->  1 | Confidence Score [8.91813867]
#
# Detection:: Location -> (132, 60)
# Scale ->  1 | Confidence Score [71.2038741]
#
# Detection:: Location -> (144, 60)
# Scale ->  1 | Confidence Score [58.48229625]
#
# Detection:: Location -> (156, 60)
# Scale ->  1 | Confidence Score [173.9888848]
#
# Detection:: Location -> (168, 60)
# Scale ->  1 | Confidence Score [78.03206097]
#
# Detection:: Location -> (180, 60)
# Scale ->  1 | Confidence Score [131.5523582]
#
# Detection:: Location -> (192, 60)
# Scale ->  1 | Confidence Score [97.37622586]
#
# Detection:: Location -> (204, 60)
# Scale ->  1 | Confidence Score [67.4210182]
#
# Detection:: Location -> (24, 72)
# Scale ->  1 | Confidence Score [214.08701573]
#
# Detection:: Location -> (36, 72)
# Scale ->  1 | Confidence Score [192.76589392]
#
# Detection:: Location -> (72, 72)
# Scale ->  1 | Confidence Score [89.97606925]
#
# Detection:: Location -> (84, 72)
# Scale ->  1 | Confidence Score [10.82858091]
#
# Detection:: Location -> (96, 72)
# Scale ->  1 | Confidence Score [46.5770753]
#
# Detection:: Location -> (108, 72)
# Scale ->  1 | Confidence Score [20.24490056]
#
# Detection:: Location -> (120, 72)
# Scale ->  1 | Confidence Score [119.38236234]
#
# Detection:: Location -> (132, 72)
# Scale ->  1 | Confidence Score [67.53124161]
#
# Detection:: Location -> (144, 72)
# Scale ->  1 | Confidence Score [68.05996779]
#
# Detection:: Location -> (156, 72)
# Scale ->  1 | Confidence Score [125.15688868]
#
# Detection:: Location -> (168, 72)
# Scale ->  1 | Confidence Score [55.45982015]
#
# Detection:: Location -> (180, 72)
# Scale ->  1 | Confidence Score [128.64999528]
#
# Detection:: Location -> (192, 72)
# Scale ->  1 | Confidence Score [127.03520916]
#
# Detection:: Location -> (204, 72)
# Scale ->  1 | Confidence Score [64.31410463]
#
# Detection:: Location -> (24, 84)
# Scale ->  1 | Confidence Score [172.22720067]
#
# Detection:: Location -> (36, 84)
# Scale ->  1 | Confidence Score [120.16241604]
#
# Detection:: Location -> (48, 84)
# Scale ->  1 | Confidence Score [3.90246153]
#
# Detection:: Location -> (72, 84)
# Scale ->  1 | Confidence Score [196.29260282]
#
# Detection:: Location -> (84, 84)
# Scale ->  1 | Confidence Score [47.12650974]
#
# Detection:: Location -> (96, 84)
# Scale ->  1 | Confidence Score [71.26642814]
#
# Detection:: Location -> (108, 84)
# Scale ->  1 | Confidence Score [126.7297074]
#
# Detection:: Location -> (120, 84)
# Scale ->  1 | Confidence Score [50.46705588]
#
# Detection:: Location -> (132, 84)
# Scale ->  1 | Confidence Score [76.66227685]
#
# Detection:: Location -> (144, 84)
# Scale ->  1 | Confidence Score [22.74194749]
#
# Detection:: Location -> (156, 84)
# Scale ->  1 | Confidence Score [216.2385433]
#
# Detection:: Location -> (168, 84)
# Scale ->  1 | Confidence Score [114.95728044]
#
# Detection:: Location -> (180, 84)
# Scale ->  1 | Confidence Score [90.61865534]
#
# Detection:: Location -> (192, 84)
# Scale ->  1 | Confidence Score [86.75706461]
#
# Detection:: Location -> (204, 84)
# Scale ->  1 | Confidence Score [29.3647099]
#
# Detection:: Location -> (24, 96)
# Scale ->  1 | Confidence Score [319.61829351]
#
# Detection:: Location -> (36, 96)
# Scale ->  1 | Confidence Score [136.09324204]
#
# Detection:: Location -> (48, 96)
# Scale ->  1 | Confidence Score [54.76654386]
#
# Detection:: Location -> (60, 96)
# Scale ->  1 | Confidence Score [81.43146696]
#
# Detection:: Location -> (72, 96)
# Scale ->  1 | Confidence Score [120.85798256]
#
# Detection:: Location -> (96, 96)
# Scale ->  1 | Confidence Score [4.17174344]
#
# Detection:: Location -> (108, 96)
# Scale ->  1 | Confidence Score [123.76447208]
#
# Detection:: Location -> (120, 96)
# Scale ->  1 | Confidence Score [13.12981504]
#
# Detection:: Location -> (132, 96)
# Scale ->  1 | Confidence Score [55.55306249]
#
# Detection:: Location -> (144, 96)
# Scale ->  1 | Confidence Score [16.67487732]
#
# Detection:: Location -> (156, 96)
# Scale ->  1 | Confidence Score [135.02753342]
#
# Detection:: Location -> (168, 96)
# Scale ->  1 | Confidence Score [106.64524096]
#
# Detection:: Location -> (180, 96)
# Scale ->  1 | Confidence Score [140.67564583]
#
# Detection:: Location -> (192, 96)
# Scale ->  1 | Confidence Score [94.83695059]
#
# Detection:: Location -> (204, 96)
# Scale ->  1 | Confidence Score [114.10415635]
#
# Detection:: Location -> (0, 108)
# Scale ->  1 | Confidence Score [8.48975126]
#
# Detection:: Location -> (24, 108)
# Scale ->  1 | Confidence Score [214.05765598]
#
# Detection:: Location -> (36, 108)
# Scale ->  1 | Confidence Score [74.92895095]
#
# Detection:: Location -> (72, 108)
# Scale ->  1 | Confidence Score [199.28384886]
#
# Detection:: Location -> (84, 108)
# Scale ->  1 | Confidence Score [80.7937425]
#
# Detection:: Location -> (96, 108)
# Scale ->  1 | Confidence Score [121.10278657]
#
# Detection:: Location -> (120, 108)
# Scale ->  1 | Confidence Score [18.11387001]
#
# Detection:: Location -> (132, 108)
# Scale ->  1 | Confidence Score [28.19670371]
#
# Detection:: Location -> (144, 108)
# Scale ->  1 | Confidence Score [63.15634691]
#
# Detection:: Location -> (156, 108)
# Scale ->  1 | Confidence Score [140.68379683]
#
# Detection:: Location -> (168, 108)
# Scale ->  1 | Confidence Score [104.08001365]
#
# Detection:: Location -> (180, 108)
# Scale ->  1 | Confidence Score [140.24747237]
#
# Detection:: Location -> (192, 108)
# Scale ->  1 | Confidence Score [99.23166895]
#
# Detection:: Location -> (204, 108)
# Scale ->  1 | Confidence Score [75.73352286]
#
# Detection:: Location -> (0, 120)
# Scale ->  1 | Confidence Score [34.07678362]
#
# Detection:: Location -> (24, 120)
# Scale ->  1 | Confidence Score [294.04251049]
#
# Detection:: Location -> (36, 120)
# Scale ->  1 | Confidence Score [261.04429746]
#
# Detection:: Location -> (48, 120)
# Scale ->  1 | Confidence Score [18.43154886]
#
# Detection:: Location -> (60, 120)
# Scale ->  1 | Confidence Score [0.55613757]
#
# Detection:: Location -> (72, 120)
# Scale ->  1 | Confidence Score [223.81518794]
#
# Detection:: Location -> (84, 120)
# Scale ->  1 | Confidence Score [11.9623954]
#
# Detection:: Location -> (96, 120)
# Scale ->  1 | Confidence Score [53.78757752]
#
# Detection:: Location -> (108, 120)
# Scale ->  1 | Confidence Score [66.94970131]
#
# Detection:: Location -> (132, 120)
# Scale ->  1 | Confidence Score [55.68034709]
#
# Detection:: Location -> (144, 120)
# Scale ->  1 | Confidence Score [43.40010448]
#
# Detection:: Location -> (156, 120)
# Scale ->  1 | Confidence Score [82.14849673]
#
# Detection:: Location -> (168, 120)
# Scale ->  1 | Confidence Score [71.59608991]
#
# Detection:: Location -> (180, 120)
# Scale ->  1 | Confidence Score [93.81098221]
#
# Detection:: Location -> (192, 120)
# Scale ->  1 | Confidence Score [95.57300128]
#
# Detection:: Location -> (24, 132)
# Scale ->  1 | Confidence Score [319.12186365]
#
# Detection:: Location -> (36, 132)
# Scale ->  1 | Confidence Score [98.46307846]
#
# Detection:: Location -> (48, 132)
# Scale ->  1 | Confidence Score [114.15902557]
#
# Detection:: Location -> (60, 132)
# Scale ->  1 | Confidence Score [56.59587932]
#
# Detection:: Location -> (72, 132)
# Scale ->  1 | Confidence Score [267.78200222]
#
# Detection:: Location -> (84, 132)
# Scale ->  1 | Confidence Score [170.25448134]
#
# Detection:: Location -> (96, 132)
# Scale ->  1 | Confidence Score [148.91318703]
#
# Detection:: Location -> (108, 132)
# Scale ->  1 | Confidence Score [156.6125772]
#
# Detection:: Location -> (120, 132)
# Scale ->  1 | Confidence Score [3.92297786]
# Detection:: Location -> (156, 132)
# Scale ->  1 | Confidence Score [16.82694368]
#
# Detection:: Location -> (168, 132)
# Scale ->  1 | Confidence Score [118.62338953]
#
# Detection:: Location -> (180, 132)
# Scale ->  1 | Confidence Score [110.66082467]
#
# Detection:: Location -> (192, 132)
# Scale ->  1 | Confidence Score [115.13669765]
#
# Detection:: Location -> (204, 132)
# Scale ->  1 | Confidence Score [105.75743349]
#
# Detection:: Location -> (12, 0)
# Scale ->  2 | Confidence Score [132.76033125]
#
# Detection:: Location -> (24, 0)
# Scale ->  2 | Confidence Score [49.24214337]
#
# Detection:: Location -> (72, 0)
# Scale ->  2 | Confidence Score [223.10054637]
#
# Detection:: Location -> (84, 0)
# Scale ->  2 | Confidence Score [69.55075887]
#
# Detection:: Location -> (96, 0)
# Scale ->  2 | Confidence Score [134.08125931]
#
# Detection:: Location -> (108, 0)
# Scale ->  2 | Confidence Score [123.60033156]
#
# Detection:: Location -> (120, 0)
# Scale ->  2 | Confidence Score [106.00393191]
#
# Detection:: Location -> (144, 0)
# Scale ->  2 | Confidence Score [29.0441191]
#
# Detection:: Location -> (12, 12)
# Scale ->  2 | Confidence Score [230.4561858]
#
# Detection:: Location -> (24, 12)
# Scale ->  2 | Confidence Score [80.99316831]
#
# Detection:: Location -> (60, 12)
# Scale ->  2 | Confidence Score [52.964567]
#
# Detection:: Location -> (72, 12)
# Scale ->  2 | Confidence Score [179.53356436]
#
# Detection:: Location -> (84, 12)
# Scale ->  2 | Confidence Score [21.57798876]
#
# Detection:: Location -> (96, 12)
# Scale ->  2 | Confidence Score [174.11410565]
#
# Detection:: Location -> (108, 12)
# Scale ->  2 | Confidence Score [191.00853418]
#
# Detection:: Location -> (120, 12)
# Scale ->  2 | Confidence Score [103.77288758]
#
# Detection:: Location -> (132, 12)
# Scale ->  2 | Confidence Score [120.84878125]
#
# Detection:: Location -> (144, 12)
# Scale ->  2 | Confidence Score [7.41443274]
#
# Detection:: Location -> (0, 24)
# Scale ->  2 | Confidence Score [57.19811233]
#
# Detection:: Location -> (12, 24)
# Scale ->  2 | Confidence Score [228.20010703]
#
# Detection:: Location -> (24, 24)
# Scale ->  2 | Confidence Score [144.82275709]
#
# Detection:: Location -> (48, 24)
# Scale ->  2 | Confidence Score [16.50590177]
#
# Detection:: Location -> (60, 24)
# Scale ->  2 | Confidence Score [34.31763239]
#
# Detection:: Location -> (72, 24)
# Scale ->  2 | Confidence Score [28.45609849]
#
# Detection:: Location -> (96, 24)
# Scale ->  2 | Confidence Score [71.88378993]
#
# Detection:: Location -> (108, 24)
# Scale ->  2 | Confidence Score [130.52857287]
#
# Detection:: Location -> (132, 24)
# Scale ->  2 | Confidence Score [151.24346724]
#
# Detection:: Location -> (144, 24)
# Scale ->  2 | Confidence Score [68.41738129]
#
# Detection:: Location -> (0, 36)
# Scale ->  2 | Confidence Score [110.98070085]
#
# Detection:: Location -> (12, 36)
# Scale ->  2 | Confidence Score [281.95785003]
#
# Detection:: Location -> (24, 36)
# Scale ->  2 | Confidence Score [159.14078521]
#
# Detection:: Location -> (60, 36)
# Scale ->  2 | Confidence Score [111.97428886]
#
# Detection:: Location -> (72, 36)
# Scale ->  2 | Confidence Score [99.12146364]
#
# Detection:: Location -> (84, 36)
# Scale ->  2 | Confidence Score [77.47637228]
#
# Detection:: Location -> (96, 36)
# Scale ->  2 | Confidence Score [143.05499465]
#
# Detection:: Location -> (108, 36)
# Scale ->  2 | Confidence Score [112.72848765]
#
# Detection:: Location -> (120, 36)
# Scale ->  2 | Confidence Score [70.14190563]
#
# Detection:: Location -> (132, 36)
# Scale ->  2 | Confidence Score [91.81145245]
#
# Detection:: Location -> (144, 36)
# Scale ->  2 | Confidence Score [71.82345046]
#
# Detection:: Location -> (0, 48)
# Scale ->  2 | Confidence Score [48.47046759]
#
# Detection:: Location -> (12, 48)
# Scale ->  2 | Confidence Score [141.73209084]
#
# Detection:: Location -> (24, 48)
# Scale ->  2 | Confidence Score [75.23860053]
#
# Detection:: Location -> (36, 48)
# Scale ->  2 | Confidence Score [44.03088621]
#
# Detection:: Location -> (60, 48)
# Scale ->  2 | Confidence Score [42.66938202]
#
# Detection:: Location -> (72, 48)
# Scale ->  2 | Confidence Score [124.66771192]
#
# Detection:: Location -> (84, 48)
# Scale ->  2 | Confidence Score [89.08299074]
#
# Detection:: Location -> (96, 48)
# Scale ->  2 | Confidence Score [93.31702746]
#
# Detection:: Location -> (108, 48)
# Scale ->  2 | Confidence Score [158.18541333]
#
# Detection:: Location -> (120, 48)
# Scale ->  2 | Confidence Score [49.38956569]
#
# Detection:: Location -> (132, 48)
# Scale ->  2 | Confidence Score [34.58653865]
#
# Detection:: Location -> (144, 48)
# Scale ->  2 | Confidence Score [30.8941692]
#
# Detection:: Location -> (0, 60)
# Scale ->  2 | Confidence Score [18.45802244]
#
# Detection:: Location -> (12, 60)
# Scale ->  2 | Confidence Score [201.66111762]
#
# Detection:: Location -> (24, 60)
# Scale ->  2 | Confidence Score [112.21153619]
#
# Detection:: Location -> (36, 60)
# Scale ->  2 | Confidence Score [160.48978559]
# /Users/miracle/anaconda2/envs/py3/lib/python3.6/site-packages/skimage/transform/_warps.py:24: UserWarning: The default multichannel argument (None) is deprecated.  Please specify either True or False explicitly.  multichannel will default to False starting with release 0.16.
#   warn('The default multichannel argument (None) is deprecated.  Please '
# Detection:: Location -> (72, 60)
# Scale ->  2 | Confidence Score [200.42501511]
#
# Detection:: Location -> (84, 60)
# Scale ->  2 | Confidence Score [83.58685461]
#
# Detection:: Location -> (96, 60)
# Scale ->  2 | Confidence Score [68.77975443]
#
# Detection:: Location -> (108, 60)
# Scale ->  2 | Confidence Score [109.46036889]
#
# Detection:: Location -> (120, 60)
# Scale ->  2 | Confidence Score [76.30407166]
#
# Detection:: Location -> (132, 60)
# Scale ->  2 | Confidence Score [83.21867937]
#
# Detection:: Location -> (144, 60)
# Scale ->  2 | Confidence Score [140.11042164]
#
# Detection:: Location -> (0, 72)
# Scale ->  2 | Confidence Score [148.88384427]
#
# Detection:: Location -> (12, 72)
# Scale ->  2 | Confidence Score [178.86894773]
#
# Detection:: Location -> (24, 72)
# Scale ->  2 | Confidence Score [104.71299686]
#
# Detection:: Location -> (36, 72)
# Scale ->  2 | Confidence Score [4.11880414]
#
# Detection:: Location -> (72, 72)
# Scale ->  2 | Confidence Score [136.48147108]
#
# Detection:: Location -> (84, 72)
# Scale ->  2 | Confidence Score [149.22504849]
#
# Detection:: Location -> (108, 72)
# Scale ->  2 | Confidence Score [228.42662037]
#
# Detection:: Location -> (120, 72)
# Scale ->  2 | Confidence Score [145.24259592]
#
# Detection:: Location -> (132, 72)
# Scale ->  2 | Confidence Score [105.74103513]
#
# Detection:: Location -> (144, 72)
# Scale ->  2 | Confidence Score [35.74416392]
#
# Detection:: Location -> (0, 84)
# Scale ->  2 | Confidence Score [10.16169189]
#
# Detection:: Location -> (12, 84)
# Scale ->  2 | Confidence Score [109.94207562]
#
# Detection:: Location -> (24, 84)
# Scale ->  2 | Confidence Score [125.01209104]
#
# Detection:: Location -> (36, 84)
# Scale ->  2 | Confidence Score [44.16116703]
#
# Detection:: Location -> (60, 84)
# Scale ->  2 | Confidence Score [16.61618255]
#
# Detection:: Location -> (72, 84)
# Scale ->  2 | Confidence Score [99.36610584]
#
# Detection:: Location -> (84, 84)
# Scale ->  2 | Confidence Score [60.85217742]
#
# Detection:: Location -> (108, 84)
# Scale ->  2 | Confidence Score [89.27560208]
#
# Detection:: Location -> (120, 84)
# Scale ->  2 | Confidence Score [112.85687222]
#
# Detection:: Location -> (132, 84)
# Scale ->  2 | Confidence Score [118.08642269]
#
# Detection:: Location -> (0, 96)
# Scale ->  2 | Confidence Score [40.9432988]
#
# Detection:: Location -> (24, 96)
# Scale ->  2 | Confidence Score [177.21709314]
#
# Detection:: Location -> (36, 96)
# Scale ->  2 | Confidence Score [103.01330272]
#
# Detection:: Location -> (48, 96)
# Scale ->  2 | Confidence Score [35.43485183]
#
# Detection:: Location -> (60, 96)
# Scale ->  2 | Confidence Score [73.34202167]
#
# Detection:: Location -> (72, 96)
# Scale ->  2 | Confidence Score [89.13424071]
#
# Detection:: Location -> (84, 96)
# Scale ->  2 | Confidence Score [89.29709678]
#
# Detection:: Location -> (96, 96)
# Scale ->  2 | Confidence Score [3.72180891]
#
# Detection:: Location -> (108, 96)
# Scale ->  2 | Confidence Score [135.90266317]
#
# Detection:: Location -> (120, 96)
# Scale ->  2 | Confidence Score [112.84525094]
#
# Detection:: Location -> (132, 96)
# Scale ->  2 | Confidence Score [59.38685086]
#
# Detection:: Location -> (144, 96)
# Scale ->  2 | Confidence Score [23.62481427]
#
# Detection:: Location -> (0, 0)
# Scale ->  3 | Confidence Score [55.54021684]
#
# Detection:: Location -> (24, 0)
# Scale ->  3 | Confidence Score [156.06333597]
#
# Detection:: Location -> (36, 0)
# Scale ->  3 | Confidence Score [77.30294172]
#
# Detection:: Location -> (48, 0)
# Scale ->  3 | Confidence Score [27.71383265]
#
# Detection:: Location -> (60, 0)
# Scale ->  3 | Confidence Score [73.4330041]
#
# Detection:: Location -> (72, 0)
# Scale ->  3 | Confidence Score [104.46969747]
#
# Detection:: Location -> (84, 0)
# Scale ->  3 | Confidence Score [96.70750149]
#
# Detection:: Location -> (96, 0)
# Scale ->  3 | Confidence Score [124.19387191]
#
# Detection:: Location -> (108, 0)
# Scale ->  3 | Confidence Score [57.87454962]
#
# Detection:: Location -> (0, 12)
# Scale ->  3 | Confidence Score [101.56611254]
#
# Detection:: Location -> (12, 12)
# Scale ->  3 | Confidence Score [35.70971066]
#
# Detection:: Location -> (24, 12)
# Scale ->  3 | Confidence Score [27.86056779]
#
# Detection:: Location -> (36, 12)
# Scale ->  3 | Confidence Score [147.04521475]
#
# Detection:: Location -> (48, 12)
# Scale ->  3 | Confidence Score [90.29353618]
#
# Detection:: Location -> (60, 12)
# Scale ->  3 | Confidence Score [107.33570792]
#
# Detection:: Location -> (72, 12)
# Scale ->  3 | Confidence Score [84.15461539]
#
# Detection:: Location -> (84, 12)
# Scale ->  3 | Confidence Score [36.05513168]
#
# Detection:: Location -> (96, 12)
# Scale ->  3 | Confidence Score [103.87020637]
#
# Detection:: Location -> (108, 12)
# Scale ->  3 | Confidence Score [105.51382148]
#
# Detection:: Location -> (0, 24)
# Scale ->  3 | Confidence Score [158.20221816]
#
# Detection:: Location -> (12, 24)
# Scale ->  3 | Confidence Score [4.12369257]
#
# Detection:: Location -> (24, 24)
# Scale ->  3 | Confidence Score [76.25439438]
#
# Detection:: Location -> (36, 24)
# Scale ->  3 | Confidence Score [92.59799482]
#
# Detection:: Location -> (48, 24)
# Scale ->  3 | Confidence Score [164.35521878]
#
# Detection:: Location -> (60, 24)
# Scale ->  3 | Confidence Score [133.82109971]
# /Users/miracle/anaconda2/envs/py3/lib/python3.6/site-packages/skimage/transform/_warps.py:24: UserWarning: The default multichannel argument (None) is deprecated.  Please specify either True or False explicitly.  multichannel will default to False starting with release 0.16.
#   warn('The default multichannel argument (None) is deprecated.  Please '
# /Users/miracle/anaconda2/envs/py3/lib/python3.6/site-packages/skimage/transform/_warps.py:24: UserWarning: The default multichannel argument (None) is deprecated.  Please specify either True or False explicitly.  multichannel will default to False starting with release 0.16.
#   warn('The default multichannel argument (None) is deprecated.  Please '
# Detection:: Location -> (72, 24)
# Scale ->  3 | Confidence Score [146.91424195]
#
# Detection:: Location -> (84, 24)
# Scale ->  3 | Confidence Score [80.18686481]
#
# Detection:: Location -> (96, 24)
# Scale ->  3 | Confidence Score [19.44923878]
#
# Detection:: Location -> (108, 24)
# Scale ->  3 | Confidence Score [46.33007949]
#
# Detection:: Location -> (0, 36)
# Scale ->  3 | Confidence Score [39.4342486]
#
# Detection:: Location -> (12, 36)
# Scale ->  3 | Confidence Score [23.12613535]
#
# Detection:: Location -> (24, 36)
# Scale ->  3 | Confidence Score [74.71486268]
#
# Detection:: Location -> (36, 36)
# Scale ->  3 | Confidence Score [158.35660639]
#
# Detection:: Location -> (48, 36)
# Scale ->  3 | Confidence Score [61.61585598]
#
# Detection:: Location -> (60, 36)
# Scale ->  3 | Confidence Score [130.90831251]
#
# Detection:: Location -> (72, 36)
# Scale ->  3 | Confidence Score [60.89437575]
#
# Detection:: Location -> (84, 36)
# Scale ->  3 | Confidence Score [111.45507137]
#
# Detection:: Location -> (96, 36)
# Scale ->  3 | Confidence Score [56.96420561]
#
# Detection:: Location -> (108, 36)
# Scale ->  3 | Confidence Score [75.30409186]
#
# Detection:: Location -> (0, 48)
# Scale ->  3 | Confidence Score [26.05576398]
#
# Detection:: Location -> (12, 48)
# Scale ->  3 | Confidence Score [94.51530433]
#
# Detection:: Location -> (24, 48)
# Scale ->  3 | Confidence Score [87.82233976]
#
# Detection:: Location -> (48, 48)
# Scale ->  3 | Confidence Score [41.75362163]
#
# Detection:: Location -> (72, 48)
# Scale ->  3 | Confidence Score [92.04998715]
#
# Detection:: Location -> (84, 48)
# Scale ->  3 | Confidence Score [97.79060301]
#
# Detection:: Location -> (96, 48)
# Scale ->  3 | Confidence Score [83.31311664]
#
# Detection:: Location -> (108, 48)
# Scale ->  3 | Confidence Score [64.07438041]
#
# Detection:: Location -> (12, 60)
# Scale ->  3 | Confidence Score [98.94251611]
#
# Detection:: Location -> (24, 60)
# Scale ->  3 | Confidence Score [81.15108498]
#
# Detection:: Location -> (48, 60)
# Scale ->  3 | Confidence Score [117.3984885]
#
# Detection:: Location -> (60, 60)
# Scale ->  3 | Confidence Score [29.6580589]
#
# Detection:: Location -> (72, 60)
# Scale ->  3 | Confidence Score [59.65205875]
#
# Detection:: Location -> (84, 60)
# Scale ->  3 | Confidence Score [58.60227292]
#
# Detection:: Location -> (96, 60)
# Scale ->  3 | Confidence Score [103.12145264]
#
# Detection:: Location -> (108, 60)
# Scale ->  3 | Confidence Score [84.96184137]
#
# Detection:: Location -> (12, 0)
# Scale ->  4 | Confidence Score [32.99621477]
#
# Detection:: Location -> (24, 0)
# Scale ->  4 | Confidence Score [172.58636493]
#
# Detection:: Location -> (36, 0)
# Scale ->  4 | Confidence Score [112.08340106]
#
# Detection:: Location -> (48, 0)
# Scale ->  4 | Confidence Score [22.23810567]
#
# Detection:: Location -> (60, 0)
# Scale ->  4 | Confidence Score [132.97443242]
#
# Detection:: Location -> (72, 0)
# Scale ->  4 | Confidence Score [30.48257438]
#
# Detection:: Location -> (24, 12)
# Scale ->  4 | Confidence Score [122.031171]
#
# Detection:: Location -> (36, 12)
# Scale ->  4 | Confidence Score [169.07726911]
#
# Detection:: Location -> (60, 12)
# Scale ->  4 | Confidence Score [28.93021895]
#
# Detection:: Location -> (72, 12)
# Scale ->  4 | Confidence Score [84.78081875]
#
# Detection:: Location -> (0, 24)
# Scale ->  4 | Confidence Score [47.2762149]
#
# Detection:: Location -> (24, 24)
# Scale ->  4 | Confidence Score [102.69167294]
#
# Detection:: Location -> (36, 24)
# Scale ->  4 | Confidence Score [227.54615479]
#
# Detection:: Location -> (48, 24)
# Scale ->  4 | Confidence Score [68.3013982]
#
# Detection:: Location -> (60, 24)
# Scale ->  4 | Confidence Score [42.41886539]
#
# Detection:: Location -> (72, 24)
# Scale ->  4 | Confidence Score [10.85155713]
#
# Detection:: Location -> (0, 36)
# Scale ->  4 | Confidence Score [110.31209166]
#
# Detection:: Location -> (12, 36)
# Scale ->  4 | Confidence Score [20.32368012]
#
# Detection:: Location -> (24, 36)
# Scale ->  4 | Confidence Score [25.31426811]
#
# Detection:: Location -> (36, 36)
# Scale ->  4 | Confidence Score [62.82774993]
#
# Detection:: Location -> (48, 36)
# Scale ->  4 | Confidence Score [72.42600262]
#
# Detection:: Location -> (60, 36)
# Scale ->  4 | Confidence Score [44.29902985]
#
# Detection:: Location -> (72, 36)
# Scale ->  4 | Confidence Score [112.28299069]
#
# Detection:: Location -> (12, 0)
# Scale ->  5 | Confidence Score [1.15407742]
#
# Detection:: Location -> (24, 0)
# Scale ->  5 | Confidence Score [83.80991129]
#
# Detection:: Location -> (48, 0)
# Scale ->  5 | Confidence Score [18.15130258]
#
# Detection:: Location -> (0, 12)
# Scale ->  5 | Confidence Score [82.45220209]
#
# Detection:: Location -> (12, 12)
# Scale ->  5 | Confidence Score [93.78560973]
# /Users/miracle/anaconda2/envs/py3/lib/python3.6/site-packages/skimage/transform/_warps.py:24: UserWarning: The default multichannel argument (None) is deprecated.  Please specify either True or False explicitly.  multichannel will default to False starting with release 0.16.
#   warn('The default multichannel argument (None) is deprecated.  Please '
# /Users/miracle/anaconda2/envs/py3/lib/python3.6/site-packages/skimage/transform/_warps.py:24: UserWarning: The default multichannel argument (None) is deprecated.  Please specify either True or False explicitly.  multichannel will default to False starting with release 0.16.
#   warn('The default multichannel argument (None) is deprecated.  Please '
# /Users/miracle/anaconda2/envs/py3/lib/python3.6/site-packages/skimage/transform/_warps.py:24: UserWarning: The default multichannel argument (None) is deprecated.  Please specify either True or False explicitly.  multichannel will default to False starting with release 0.16.
#   warn('The default multichannel argument (None) is deprecated.  Please '
# Detection:: Location -> (24, 12)
# Scale ->  5 | Confidence Score [170.77876251]
#
# Detection:: Location -> (36, 12)
# Scale ->  5 | Confidence Score [56.77668887]
#
# Detection:: Location -> (48, 12)
# Scale ->  5 | Confidence Score [11.02318982]
#
# Detection:: Location -> (0, 0)
# Scale ->  6 | Confidence Score [5.98982572]
#
# Detection:: Location -> (12, 0)
# Scale ->  6 | Confidence Score [77.60263965]

# %%
# Out:
# Python 3.6.1 :: Anaconda custom (x86_64)
